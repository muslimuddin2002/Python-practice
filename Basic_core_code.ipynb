# %% [markdown]
# <a href="https://colab.research.google.com/github/muslimuddin2002/Python-practice/blob/main/Basic_core_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic Login System
username = "MK Fundation"
password = "2002+2004"

u = input("Username: ")
p = input("Password: ")

if u == username and p == password:
    print("Login Successful")

else:
    print("Wrong username or password")
# Out:
# Username: hjh
# Password: 25
# Wrong username or password

# %%
# Character Counter
text = input("Enter text: ")

print("Total characters:", len(text))
# Out:
# Enter text: MK MuslimuddinKhadijakhatun
# Total characters: 27

# %%
# Simple Alarm
import time

seconds = int(input("Set time in seconds: "))

time.sleep(seconds)

print("Alarm! Time finished")
# Out:
# Set time in seconds: 5
# Alarm! Time finished

# %%
# Random Color Generator
import random

colors = ["Red", "Blue", "Green", "Black", "White"]

print("Random Color:", random.choice(colors))
# Out:
# Random Color: Black

# %%
# ASCII Value Finder
char = input("Enter a character: ")

print("ASCII Value:", ord(char))
# Out:
# Enter a character: A
# ASCII Value: 65

# %%
# Mini Banking System
balance = 1000000

while True:
    print("\n1.Check Balance")
    print("2.Deposit")
    print("3.Withdraw")
    print("4.Exit")

    choice = input("Choose: ")

    if choice == "1":
        print("Balance:", balance)

    elif choice == "2":
        amount = int(input("Enter amount: "))
        balance += amount

    elif choice == "3":
        amount = int(input("Enter amount: "))

        if amount <= balance:
            balance -= amount

        else:
            print("Insufficient Balance")

    elif choice == "4":
        break
# Out:
# 1.Check Balance
# 2.Deposit
# 3.Withdraw
# 4.Exit
# Choose: 1
# Balance: 1000000
#
# 1.Check Balance
# 2.Deposit
# 3.Withdraw
# 4.Exit
# Choose: 4

# %%
# Email Validator
email = input("Enter email: ")

if "@" in email and "." in email:
    print("Valid Email")
else:
    print("Invalid Email")
# Out:
# Enter email: muslimkhadija@gmail.com
# Valid Email

# %%
# List Sorter
numbers = [5, 2, 9, 1, 7]

numbers.sort()

print(numbers)
# Out:
# [1, 2, 5, 7, 9]

# %%
# Age Calculator
from datetime import date
from calendar import monthrange

def calculate_age(birth_year, birth_month, birth_day):
    today = date.today()  # LIVE system date (auto)

    birth_date = date(birth_year, birth_month, birth_day)

    years = today.year - birth_date.year
    months = today.month - birth_date.month
    days = today.day - birth_date.day

    # If days negative → borrow days from previous month
    if days < 0:
        months -= 1

        prev_month = today.month - 1
        prev_year = today.year

        if prev_month == 0:
            prev_month = 12
            prev_year -= 1

        days += monthrange(prev_year, prev_month)[1]

    # If months negative → borrow 12 months
    if months < 0:
        years -= 1
        months += 12

    return years, months, days


# INPUT
birth_year = int(input("Enter birth year: "))
birth_month = int(input("Enter birth month: "))
birth_day = int(input("Enter birth day: "))

y, m, d = calculate_age(birth_year, birth_month, birth_day)

print(f"\nYour Exact Age:")
print(f"{y} Years, {m} Months, {d} Days")
# Out:
# Enter birth year: 2002
# Enter birth month: 12
# Enter birth day: 16
#
# Your Exact Age:
# 23 Years, 5 Months, 26 Days

# %%
# Unique Number Finder
numbers = [1, 2, 2, 3, 4, 4, 5]

unique = list(set(numbers))

print(unique)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Currency Converter
usd = float(input("Enter USD: "))

bdt = usd * 122

print("BDT:", bdt)
# Out:
# Enter USD: 44
# BDT: 5368.0

# %%
# Currency Converter
bdt = float(input("Enter BDT: "))

usd = bdt / 122

print("USD:", usd)
# Out:
# Enter BDT: 244
# USD: 2.0

# %%
# Username Generator
name = input("Enter your name: ")

username = name.lower() + "123"

print("Username:", username)
# Out:
# Enter your name: muslim
# Username: muslim123

# %%
# Remove Duplicate from List
numbers = [1, 1, 2, 3, 3, 4]

new_list = []

for n in numbers:
    if n not in new_list:
        new_list.append(n)

print(new_list)
# Out:
# [1, 2, 3, 4]

# %%
# Mini ATM PIN Check
pin = "1234"

user_pin = input("Enter PIN: ")

if user_pin == pin:
    print("Access Granted")

else:
    print("Wrong PIN")
# Out:
# Enter PIN: 1234
# Access Granted

# %%
# Text to Uppercase
text = input("Enter text: ")

print(text.upper())
# Out:
# Enter text: muslim
# MUSLIM

# %%
# Swap Two Numbers (without temp)
a = int(input("A: "))
b = int(input("B: "))

a, b = b, a

print("After swap A =", a)
print("After swap B =", b)
# Out:
# A: 2
# B: 5
# After swap A = 5
# After swap B = 2

# %%
# Find Average of Numbers
nums = [1, 2, 3, 4, 5]

print("Average:", sum(nums)/len(nums))
# Out:
# Average: 3.0

# %%
# Find Minimum in List (manual)
nums = [10, 50, 30, 80, 20]

min_num = nums[0]

for i in nums:
    if i < min_num:
        min_num = i

print("Min:", min_num)
# Out:
# Min: 10

# %%
# Check Number Range
num = int(input("Enter number: "))

if 1 <= num <= 100:
    print("Inside range")
else:
    print("Outside range")
# Out:
# Enter number: 1002
# Outside range

# %%
# Count Even Numbers in List
nums = [1,2,3,4,5,6,7,8]

count = 0

for i in nums:
    if i % 2 == 0:
        count += 1

print(count)
# Out:
# 4

# %%
# Count Specific Letter
text = input("Enter text: ")

ch = input("Which letter to count: ")

print(text.count(ch))
# Out:
# Enter text: tgy
# Which letter to count: y
# 1

# %%
# if Statements
score = 90

if score >= 80:
   print('You pass the course!')
# Out:
# You pass the course!

# %%
# else Statements
score = 70

if score >= 80:
   print('You pass the course!')
else:
   print('You do not pass the course!')
# Out:
# You do not pass the course!

# %%
# elif Statements
score = 70

if score >= 80:
   print('You pass the course with flying colors!')

elif score > 65:
   print('You pass the course! Talk to your instructor.')

else:
   print('You do not pass the course!')
# Out:
# You pass the course! Talk to your instructor.

# %%
# for loops with range()
for i in range(3):
  print(i)
# Out:
# 0
# 1
# 2

# %%
# Nested for loops
teams = [['Jody', 'Abe'], ['Abhishek', 'Kim'], ['Taylor', 'Jen']]
for team in teams:
  for name in team:
    print(name)
# Out:
# Jody
# Abe
# Abhishek
# Kim
# Taylor
# Jen

# %%
# while loops
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# try, except and finally clauses
nums = [5, 2, 3, 10]

try:
   avg = sum(nums) / len(nums)
   print('The average of the list is: ', avg)

except:
   print('Cannot compute average - make sure you enter a list of integers!')

finally:
   print('Feel free to rerun the code with another list of integers!')
# Out:
# The average of the list is:  5.0
# Feel free to rerun the code with another list of integers!
