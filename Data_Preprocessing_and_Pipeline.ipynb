# %% [markdown]
# <a href="https://colab.research.google.com/github/muslimuddin2002/Python-practice/blob/main/Data_Preprocessing_and_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Load the Data
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler



# TODO: Load the housing data
df = pd.read_csv('/content/drive/MyDrive/datasets/Housing.csv')

# TODO: How many houses are there?
print(f"Number of houses: ___",df.shape)  # Fill this

# TODO: Show first 3 houses
print("\nFirst 3 house:")
print(df.head(3))
# Your code here
# Out:
# Number of houses: ___ (545, 13)
#
# First 3 house:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished

# %%
# Look at Columns
# TODO: Show all column names
print("\nColumns:")
print(df.columns)

# Your code here

# TODO: Show data types of columns
print("\nData types:")
print(df.dtypes)
# Out:
# Columns:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')
#
# Data types:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
#Convert Yes/No to 1/0
# Check what's in our data
print("Current mainroad values:", df['mainroad'].head())
# Shows: yes, no, yes, yes, no

# Models need numbers, not text!
# We need: yes → 1, no → 0
# Out:
# Current mainroad values: 0    yes
# 1    yes
# 2    yes
# 3    yes
# 4    yes
# Name: mainroad, dtype: object

# %%
# Split into Train and Test

# Separate input (X) and output (y)
X = df.drop('price', axis=1)   # 12 columns (features)
y = df['price']                # 1 column (target)

print("X shape:", X.shape)
print("y shape:", y.shape)

# Split: 80% train, 20% test
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,      # 20% test
    random_state=42     # same result every time
)

print(f"\nWe will train with: {len(X_train)} houses")
print(f"We will test with: {len(X_test)} houses")
# Out:
# X shape: (545, 12)
# y shape: (545,)
#
# We will train with: 436 houses
# We will test with: 109 houses

# %%
#Apply StandardScaler
# Area is huge (1650-13300), Bedrooms is small (1-6)!
#Your Code here
# Apply StandardScaler
# Area is huge (1650-13300), Bedrooms is small (1-6)!

from sklearn.preprocessing import StandardScaler
import pandas as pd

# Convert ALL categorical columns to numeric using one-hot encoding
X_train = pd.get_dummies(X_train, drop_first=True)
X_test = pd.get_dummies(X_test, drop_first=True)

# Make sure train & test have same columns
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

# Create scaler
scaler = StandardScaler()

# Learn from training data and scale it
X_train_scaled = scaler.fit_transform(X_train)

# Scale test data (just transform, don't fit)
X_test_scaled = scaler.transform(X_test)

print("\nAfter scaling:")
print("All features now have similar range!")

# SSC-style example
print(f"Example - First house area before scaling: {X_train.values[0][0]}")
print(f"Example - First house area after scaling: {X_train_scaled[0][0]:.2f}")
# Out:
# After scaling:
# All features now have similar range!
# Example - First house area before scaling: 6000
# Example - First house area after scaling: 0.38

# %%
#train and test model
#your code here

# %%
# Predict a House Price
# New house details:
# area=5000, bedrooms=3, bathrooms=2, stories=2,
# mainroad=yes, guestroom=no, basement=yes,
# hotwaterheating=no, airconditioning=yes,
# parking=2, prefarea=yes, furnishingstatus=furnished
#your code here
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
import joblib
import numpy as np

# Example training data
X_train = np.array([[5000, 3, 2, 2, 1, 0, 1, 0, 1, 2, 1, 2]])  # Add all your training rows
y_train = np.array([450000])  # Corresponding prices

# Scale the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Train model
model = LinearRegression()
model.fit(X_train_scaled, y_train)

# Save model and scaler
joblib.dump(model, 'my_model.pkl')
joblib.dump(scaler, 'my_scaler.pkl')

print("Model and scaler saved successfully!")
# Out:
# Model and scaler saved successfully!
