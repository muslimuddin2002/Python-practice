# %% [markdown]
# <a href="https://colab.research.google.com/github/muslimuddin2002/Python-practice/blob/main/python_bascis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Write a program to perform the subtraction, multipllication and division
num1 = 1453.89
num2 = 345.568

subtraction = num1 - num2
Multipllication = num1*num2
print("subtraction : {:.1f}%".format(subtraction))
print("Multipllication :{:.3f}".format(Multipllication))
# Out:
# subtraction : 1108.3%
# Multipllication :502417.860
